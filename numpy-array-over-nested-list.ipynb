# %% [markdown]
# # Numpy Array over Nested Lists

# %%
import numpy as np
import time

# %%
l = []
lsub = []
for i in range(100):
    lsub=[]
    for j in range(100):
        lsub.append(0)
    l.extend([lsub])
    
a = np.zeros((100,100))

tl1 = time.time()
for i in range(100):
    for j in range(100):
        l[i][j] = l[i][j] + 5

        
tl2 = time.time()
t1 = tl2 - tl1
ta1 = time.time()
ArrayOp = "a=a+10"

ta2 = time.time()
ta = ta2 - ta1
print(ta,t1)
# Out:
# 5.0067901611328125e-05 0.003570556640625
